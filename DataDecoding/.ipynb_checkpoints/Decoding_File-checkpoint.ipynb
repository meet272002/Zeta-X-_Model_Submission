# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd

# %%
df_accident = pd.read_csv("dft-road-casualty-statistics-collision-2024.csv")

# %%
expected_columns = ['Accident_Index', 'Accident Date', 'Day_of_Week', 'Junction_Control',
       'Junction_Detail', 'Accident_Severity', 'Latitude', 'Light_Conditions',
       'Local_Authority_(District)', 'Carriageway_Hazards', 'Longitude',
       'Number_of_Casualties', 'Number_of_Vehicles', 'Police_Force',
       'Road_Surface_Conditions', 'Road_Type', 'Speed_limit', 'Time',
       'Urban_or_Rural_Area', 'Weather_Conditions']

# %%
column = {'date':'Accident Date',
          'day_of_week':'Day_of_Week',
          'junction_control':'Junction_Control',
          'junction_detail':'Junction_Detail',
          'collision_severity':'Accident_Severity',
          'latitude':'Latitude','longitude':'Longitude',
          'light_conditions':'Light_Conditions',
          'local_authority_district':'Local_Authority_(District)',
          'carriageway_hazards':'Carriageway_Hazards',
          'number_of_casualties':'Number_of_Casualties',
          'number_of_vehicles':'Number_of_Vehicles',
          'police_force':'Police_Force',
          'road_surface_conditions':'Road_Surface_Conditions',
          'road_type':'Road_Type',
          'speed_limit':'Speed_limit',
          'time':'Time',
          'urban_or_rural_area':'Urban_or_Rural_Area',
          'weather_conditions':'Weather_Conditions',
#           'vehicle_type':'Vehicle_Type',
          'collision_index':'Accident_Index'}
df_accident = df_accident.rename(columns=column)
df_accident.columns
# Out:
# Index(['Accident_Index', 'collision_year', 'collision_ref_no',
#        'location_easting_osgr', 'location_northing_osgr', 'Longitude',
#        'Latitude', 'Police_Force', 'Accident_Severity', 'Number_of_Vehicles',
#        'Number_of_Casualties', 'Accident Date', 'Day_of_Week', 'Time',
#        'Local_Authority_(District)', 'local_authority_ons_district',
#        'local_authority_highway', 'local_authority_highway_current',
#        'first_road_class', 'first_road_number', 'Road_Type', 'Speed_limit',
#        'junction_detail_historic', 'Junction_Detail', 'Junction_Control',
#        'second_road_class', 'second_road_number',
#        'pedestrian_crossing_human_control_historic',
#        'pedestrian_crossing_physical_facilities_historic',
#        'pedestrian_crossing', 'Light_Conditions', 'Weather_Conditions',
#        'Road_Surface_Conditions', 'special_conditions_at_site',
#        'carriageway_hazards_historic', 'Carriageway_Hazards',
#        'Urban_or_Rural_Area', 'did_police_officer_attend_scene_of_accident',
#        'trunk_road_flag', 'lsoa_of_accident_location',
#        'enhanced_severity_collision', 'collision_injury_based',
#        'collision_adjusted_severity_serious',
#        'collision_adjusted_severity_slight'],
#       dtype='object')

# %%
df_accident_expected = df_accident[expected_columns]
# df_accident['vehicle_type']

# %%
df_accident_expected.head(20)
# Out:
#    Accident_Index Accident Date  Day_of_Week  Junction_Control  \
# 0   202417H103224    03/05/2024            6                 4
# 1   202417M217924    07/11/2024            5                 4
# 2   202417S204524    18/04/2024            5                -1
# 3   2024481510889    16/05/2024            5                 2
# 4   2024481563500    26/07/2024            6                 4
# 5   202417S114624    19/12/2024            5                 2
# 6   2024481561505    27/06/2024            5                 4
# 7   202417S203724    07/04/2024            1                -1
# 8   202417S303424    27/03/2024            4                -1
# 9   202417M109924    27/06/2024            5                 4
# 10  202417M108324    15/06/2024            7                 4
# 11  202417L103324    14/04/2024            1                 4
# 12  202417L109424    25/09/2024            4                -1
# 13  202417S111024    06/10/2024            1                -1
# 14  202417M204924    19/04/2024            6                 4
# 15  202417M112924    30/07/2024            3                 2
# 16  202417S206024    22/05/2024            4                -1
# 17  202417S112224    16/10/2024            4                -1
# 18  2024481472276    03/02/2024            7                 2
# 19  202417M114824    04/09/2024            4                 4
#
#     Junction_Detail  Accident_Severity  Latitude  Light_Conditions  \
# 0                13                  3  54.68523                 1
# 1                16                  2  54.56747                 4
# 2                 0                  3  54.59946                 1
# 3                13                  2  51.51371                 4
# 4                13                  2  51.51148                 1
# 5                16                  2  54.58197                 1
# 6                13                  3  51.51664                 1
# 7                 0                  3  54.62375                 4
# 8                 0                  3  54.52764                 1
# 9                13                  3  54.55441                 1
# 10               16                  3  54.57079                 1
# 11               18                  3  54.56802                 1
# 12                0                  3  54.53394                 1
# 13                0                  2  54.56617                 4
# 14               13                  2  54.56638                 4
# 15               -1                  3  54.57061                 1
# 16                0                  2  54.60193                 1
# 17                0                  2  54.58453                 1
# 18               16                  3  51.51604                 1
# 19               13                  3  54.53639                 1
#
#     Local_Authority_(District)  Carriageway_Hazards  Longitude  \
# 0                           -1                    0   -1.24312
# 1                           -1                    0   -1.19517
# 2                           -1                    0   -1.29837
# 3                           -1                    0   -0.07626
# 4                           -1                    0   -0.08948
# 5                           -1                    0   -1.32678
# 6                           -1                    0   -0.10302
# 7                           -1                    0   -1.28513
# 8                           -1                    0   -1.32267
# 9                           -1                    0   -1.23421
# 10                          -1                    0   -1.24714
# 11                          -1                    0   -0.99627
# 12                          -1                    0   -1.04976
# 13                          -1                    0   -1.31300
# 14                          -1                    0   -1.19613
# 15                          -1                    0   -1.25560
# 16                          -1                    0   -1.30105
# 17                          -1                    0   -1.31053
# 18                          -1                    0   -0.08155
# 19                          -1                    0   -1.21291
#
#     Number_of_Casualties  Number_of_Vehicles  Police_Force  \
# 0                      1                   2            17
# 1                      1                   2            17
# 2                      2                   2            17
# 3                      1                   1            48
# 4                      2                   1            48
# 5                      1                   1            17
# 6                      1                   2            48
# 7                      2                   2            17
# 8                      1                   1            17
# 9                      1                   2            17
# 10                     1                   1            17
# 11                     2                   2            17
# 12                     1                   1            17
# 13                     1                   1            17
# 14                     1                   2            17
# 15                     5                   2            17
# 16                     3                   2            17
# 17                     1                   1            17
# 18                     1                   1            48
# 19                     1                   2            17
#
#     Road_Surface_Conditions  Road_Type  Speed_limit   Time  \
# 0                         1          6           30  07:30
# 1                         1          6           20  05:45
# 2                         2          3           40  18:10
# 3                         2          6           20  21:43
# 4                         1          6           20  16:10
# 5                         1          6           30  08:47
# 6                         1          6           20  12:48
# 7                         1          6           30  21:16
# 8                         1          6           30  15:39
# 9                         1          6           30  17:09
# 10                        2          6           30  16:04
# 11                        1          6           60  15:00
# 12                        1          6           30  12:00
# 13                        2          6           20  18:45
# 14                        1          6           30  22:35
# 15                        1          1           30  19:40
# 16                        2          3           40  21:05
# 17                        1          6           30  14:04
# 18                        1          3           20  12:30
# 19                        1          6           30  15:39
#
#     Urban_or_Rural_Area  Weather_Conditions
# 0                     1                   1
# 1                     1                   1
# 2                     2                   2
# 3                     1                   1
# 4                     1                   1
# 5                     1                   1
# 6                     1                   1
# 7                     1                   1
# 8                     2                   1
# 9                     1                   1
# 10                    1                   2
# 11                    2                   1
# 12                    1                   1
# 13                    1                   1
# 14                    1                   1
# 15                    2                   1
# 16                    1                   2
# 17                    1                   1
# 18                    1                   1
# 19                    1                   1

# %%
dict_1 = {
    'Day_of_Week' : {
        1: 'Sunday',
        2: 'Monday',
        3: 'Tuesday',
        4: 'Wednesday',
        5: 'Thursday',
        6: 'Friday',
        7: 'Saturday'
    },
    'Junction_Control' : {
        0: 'Data missing or out of range',
        1: 'Authorised person',
        2: 'Auto traffic signal',
        3: 'Stop sign',
        4: 'Give way or uncontrolled',
        -1: 'Not at junction or within 20 metres'
    },
    'Junction_Detail' : {
        0: 'Not at junction or within 20 metres',
        1: 'Roundabout',
        2: 'Mini-roundabout',
        3: 'T or staggered junction',
        5: 'Slip road',
        6: 'Crossroads',
        7: 'More than 4 arms (not roundabout)',
        8: 'Private drive or entrance',
        9: 'Other junction',
        -1: 'Data missing or out of range'
    },
    'Accident_Severity' : {
        1: 'Fatal',
        2: 'Serious',
        3: 'Slight'
    },
    'Light_Conditions' : {
        1: 'Daylight',
        4: 'Darkness - lights lit',
        5: 'Darkness - lights unlit',
        6: 'Darkness - no lighting',
        7: 'Darkness - lighting unknown',
        -1: 'Data missing or out of range'
    },
    'Carriageway_Hazards' : {
        0: 'None',
        1: 'Vehicle load on road',
        2: 'Other object on road',
        3: 'Previous accident',
        4: 'Dog on road',
        5: 'Other animal on road',
        6: 'Pedestrian in carriageway - not injured',
        7: 'Any animal in carriageway (except ridden horse)',
        -1: 'Data missing or out of range'
    },
    'Police_Force' : {
        1: 'Metropolitan Police',
        3: 'Cumbria',
        4: 'Lancashire',
        5: 'Merseyside',
        6: 'Greater Manchester',
        7: 'Cheshire',
        10: 'Northumbria',
        11: 'Durham',
        12: 'North Yorkshire',
        13: 'West Yorkshire',
        14: 'South Yorkshire',
        16: 'Humberside',
        17: 'Cleveland',
        20: 'West Midlands',
        21: 'Staffordshire',
        22: 'West Mercia',
        23: 'Warwickshire',
        30: 'Derbyshire',
        31: 'Nottinghamshire',
        32: 'Lincolnshire',
        33: 'Leicestershire',
        34: 'Northamptonshire',
        35: 'Cambridgeshire',
        36: 'Norfolk',
        37: 'Suffolk',
        40: 'Bedfordshire',
        41: 'Hertfordshire',
        42: 'Essex',
        43: 'Thames Valley',
        44: 'Hampshire',
        45: 'Surrey',
        46: 'Kent',
        47: 'Sussex',
        48: 'City of London',
        50: 'Devon and Cornwall',
        52: 'Avon and Somerset',
        53: 'Gloucestershire',
        54: 'Wiltshire',
        55: 'Dorset',
        60: 'North Wales',
        61: 'Gwent',
        62: 'South Wales',
        63: 'Dyfed-Powys',
        91: 'Northern Ireland',
        92: 'Police Scotland',
        93: 'Police Service of Northern Ireland',
        -1: 'Data missing or out of range'
    },
    'Road_Surface_Conditions' : {
        1: 'Dry',
        2: 'Wet or damp',
        3: 'Snow',
        4: 'Frost or ice',
        5: 'Flood over 3cm deep',
        6: 'Oil or diesel',
        7: 'Mud',
        -1: 'Data missing or out of range'
    },
    'Road_Type' : {
        1: 'Roundabout',
        2: 'One way street',
        3: 'Dual carriageway',
        6: 'Single carriageway',
        7: 'Slip road',
        9: 'Unknown',
        12: 'One way street/Slip road',
        -1: 'Data missing or out of range'
    },
    'Weather_Conditions' : {
        1: 'Fine no high winds',
        2: 'Raining no high winds',
        3: 'Snowing no high winds',
        4: 'Fine + high winds',
        5: 'Raining + high winds',
        6: 'Snowing + high winds',
        7: 'Fog or mist',
        8: 'Other',
        9: 'Unknown',
        -1: 'Data missing or out of range'
    },
    'Urban_or_Rural_Area' : {
        1: 'Urban',
        2: 'Rural'
    }
}

cat_columns = ['Day_of_Week', 'Junction_Control', 'Junction_Detail', 'Accident_Severity', 'Light_Conditions', 'Carriageway_Hazards', 'Police_Force', 'Road_Surface_Conditions', 'Road_Type', 'Urban_or_Rural_Area', 'Weather_Conditions']

for col in cat_columns:
    df_accident_expected[col] = df_accident_expected[col].map(dict_1[col])

# %%
# df_accident_expected.dropna(inplace=True)

# %%
df_accident_expected.isnull().sum()
# Out:
# Accident_Index                    0
# Accident Date                     0
# Day_of_Week                       0
# Junction_Control               1908
# Junction_Detail               41426
# Accident_Severity                 0
# Latitude                          0
# Light_Conditions                  0
# Local_Authority_(District)        0
# Carriageway_Hazards            6984
# Longitude                         0
# Number_of_Casualties              0
# Number_of_Vehicles                0
# Police_Force                   4167
# Road_Surface_Conditions        1670
# Road_Type                         0
# Speed_limit                       0
# Time                              0
# Urban_or_Rural_Area               3
# Weather_Conditions                0
# dtype: int64

# %%
fill_na = ['Junction_Control','Junction_Detail','Carriageway_Hazards','Police_Force','Road_Surface_Conditions','Urban_or_Rural_Area']

# %%
for col in fill_na:
    df_accident_expected[col] = df_accident_expected[col].fillna(df_accident_expected[col].mode()[0])

# %%
df_accident_expected.to_csv("Final.csv",index=False)
